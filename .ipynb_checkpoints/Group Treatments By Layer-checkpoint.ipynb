# %%
import numpy as np
import pandas as pd
import psycopg2
import seaborn as sns
import matplotlib.pyplot as plt
import scipy 
sns.set(palette="Set2")
# %matplotlib inline
from ggplot import *
import matplotlib.dates as mdates

# %%
start_date = "2014-12-01"
end_date= "2014-12-16"
sql_select = "SELECT a.measuretype, a.cultivar, a.irrigation, a.plot, a.depth, b.time, b.measurement FROM alphasensorinfo a INNER JOIN alphasensordata b ON a.sensorid=b.sensorid WHERE b.time BETWEEN '" + start_date +"' and '"+ end_date + "'"  
dbconn=psycopg2.connect(host="aklpdb22.pfr.co.nz",user="rainshelterwrite", password="luverly Jubbly", database="rainshelter")
dbcursor = dbconn.cursor()
dbcursor.execute(sql_select)
data = dbcursor.fetchall()
names = dbcursor.description
dbconn.commit()
dbconn.close()

# %%
columnnames = [column[0] for column in names]
df = pd.DataFrame(data, columns=columnnames)
df2= df.query('measuretype=="VolumetricWaterContent"')
df2
# Out:
#                    measuretype cultivar irrigation  plot         depth  \
# 0       VolumetricWaterContent    Omaka       Low    205   0-15(InRow)
# 6       VolumetricWaterContent    Omaka       Low    205  0-15(btwRow)
# 12      VolumetricWaterContent    Omaka       Low    205         15-30
# 18      VolumetricWaterContent    Omaka       Low    205         30-60
# 24      VolumetricWaterContent    Omaka       Low    205         60-90
# 30      VolumetricWaterContent    Omaka       Low    205        90-120
# 36      VolumetricWaterContent    Omaka       Low    205       120-150
# 42      VolumetricWaterContent    Omaka       Low    205       150-180
# 48      VolumetricWaterContent    Dash        High   206   0-15(InRow)
# 54      VolumetricWaterContent    Dash        High   206  0-15(btwRow)
# 60      VolumetricWaterContent    Dash        High   206         15-30
# 66      VolumetricWaterContent    Dash        High   206         30-60
# 72      VolumetricWaterContent    Dash        High   206         60-90
# 78      VolumetricWaterContent    Dash        High   206        90-120
# 84      VolumetricWaterContent    Dash        High   206       120-150
# 90      VolumetricWaterContent    Dash        High   206       150-180
# 96      VolumetricWaterContent    Dash        Mid    207   0-15(InRow)
# 102     VolumetricWaterContent    Dash        Mid    207  0-15(btwRow)
# 108     VolumetricWaterContent    Dash        Mid    207         15-30
# 114     VolumetricWaterContent    Dash        Mid    207         30-60
# 120     VolumetricWaterContent    Dash        Mid    207         60-90
# 126     VolumetricWaterContent    Dash        Mid    207        90-120
# 132     VolumetricWaterContent    Dash        Mid    207       120-150
# 138     VolumetricWaterContent    Dash        Mid    207       150-180
# 144     VolumetricWaterContent    Omaka       High   208   0-15(InRow)
# 150     VolumetricWaterContent    Omaka       High   208  0-15(btwRow)
# 156     VolumetricWaterContent    Omaka       High   208         15-30
# 162     VolumetricWaterContent    Omaka       High   208         30-60
# 168     VolumetricWaterContent    Omaka       High   208         60-90
# 174     VolumetricWaterContent    Omaka       High   208        90-120
# ...                        ...      ...        ...   ...           ...
# 147276  VolumetricWaterContent    Dash        High   221         15-30
# 147282  VolumetricWaterContent    Dash        High   221         30-60
# 147288  VolumetricWaterContent    Dash        High   221         60-90
# 147294  VolumetricWaterContent    Dash        High   221        90-120
# 147300  VolumetricWaterContent    Dash        High   221       120-150
# 147306  VolumetricWaterContent    Dash        High   221       150-180
# 147312  VolumetricWaterContent    Omaka       High   222   0-15(InRow)
# 147318  VolumetricWaterContent    Omaka       High   222  0-15(btwRow)
# 147324  VolumetricWaterContent    Omaka       High   222         15-30
# 147330  VolumetricWaterContent    Omaka       High   222         30-60
# 147336  VolumetricWaterContent    Omaka       High   222         60-90
# 147342  VolumetricWaterContent    Omaka       High   222        90-120
# 147348  VolumetricWaterContent    Omaka       High   222       120-150
# 147354  VolumetricWaterContent    Omaka       High   222       150-180
# 147360  VolumetricWaterContent    Dash        Mid    223   0-15(InRow)
# 147366  VolumetricWaterContent    Dash        Mid    223  0-15(btwRow)
# 147372  VolumetricWaterContent    Dash        Mid    223         15-30
# 147378  VolumetricWaterContent    Dash        Mid    223         30-60
# 147384  VolumetricWaterContent    Dash        Mid    223         60-90
# 147390  VolumetricWaterContent    Dash        Mid    223        90-120
# 147396  VolumetricWaterContent    Dash        Mid    223       120-150
# 147402  VolumetricWaterContent    Dash        Mid    223       150-180
# 147408  VolumetricWaterContent    Omaka       Mid    224   0-15(InRow)
# 147414  VolumetricWaterContent    Omaka       Mid    224  0-15(btwRow)
# 147420  VolumetricWaterContent    Omaka       Mid    224         15-30
# 147426  VolumetricWaterContent    Omaka       Mid    224         30-60
# 147432  VolumetricWaterContent    Omaka       Mid    224         60-90
# 147438  VolumetricWaterContent    Omaka       Mid    224        90-120
# 147444  VolumetricWaterContent    Omaka       Mid    224       120-150
# 147450  VolumetricWaterContent    Omaka       Mid    224       150-180
#
#                       time  measurement
# 0      2014-12-01 00:00:00       0.0865
# 6      2014-12-01 00:00:00       0.0952
# 12     2014-12-01 00:00:00       0.1720
# 18     2014-12-01 00:00:00       0.2828
# 24     2014-12-01 00:00:00       0.3888
# 30     2014-12-01 00:00:00       0.3446
# 36     2014-12-01 00:00:00       0.4245
# 42     2014-12-01 00:00:00       0.4347
# 48     2014-12-01 00:00:00       0.2833
# 54     2014-12-01 00:00:00       0.2565
# 60     2014-12-01 00:00:00       0.2952
# 66     2014-12-01 00:00:00       0.2900
# 72     2014-12-01 00:00:00       0.3419
# 78     2014-12-01 00:00:00       0.2872
# 84     2014-12-01 00:00:00       0.4318
# 90     2014-12-01 00:00:00       0.4213
# 96     2014-12-01 00:00:00       0.0855
# 102    2014-12-01 00:00:00       0.0992
# 108    2014-12-01 00:00:00       0.1331
# 114    2014-12-01 00:00:00       0.2614
# 120    2014-12-01 00:00:00       0.3955
# 126    2014-12-01 00:00:00       0.3491
# 132    2014-12-01 00:00:00       0.4465
# 138    2014-12-01 00:00:00       0.4326
# 144    2014-12-01 00:00:00       0.2455
# 150    2014-12-01 00:00:00       0.2493
# 156    2014-12-01 00:00:00       0.2390
# 162    2014-12-01 00:00:00       0.3346
# 168    2014-12-01 00:00:00       0.3719
# 174    2014-12-01 00:00:00       0.3691
# ...                    ...          ...
# 147276 2014-12-02 07:45:00       0.2783
# 147282 2014-12-02 07:45:00       0.3213
# 147288 2014-12-02 07:45:00       0.3283
# 147294 2014-12-02 07:45:00       0.3328
# 147300 2014-12-02 07:45:00       0.2920
# 147306 2014-12-02 07:45:00       0.3853
# 147312 2014-12-02 07:45:00       0.1940
# 147318 2014-12-02 07:45:00       0.2186
# 147324 2014-12-02 07:45:00       0.2517
# 147330 2014-12-02 07:45:00       0.3081
# 147336 2014-12-02 07:45:00       0.2451
# 147342 2014-12-02 07:45:00       0.3694
# 147348 2014-12-02 07:45:00       0.3407
# 147354 2014-12-02 07:45:00       0.3604
# 147360 2014-12-02 07:45:00       0.0871
# 147366 2014-12-02 07:45:00       0.0933
# 147372 2014-12-02 07:45:00       0.1970
# 147378 2014-12-02 07:45:00       0.2454
# 147384 2014-12-02 07:45:00       0.3487
# 147390 2014-12-02 07:45:00       0.4031
# 147396 2014-12-02 07:45:00       0.4042
# 147402 2014-12-02 07:45:00       0.2566
# 147408 2014-12-02 07:45:00       0.0959
# 147414 2014-12-02 07:45:00       0.1015
# 147420 2014-12-02 07:45:00       0.1651
# 147426 2014-12-02 07:45:00       0.3008
# 147432 2014-12-02 07:45:00       0.3814
# 147438 2014-12-02 07:45:00       0.2437
# 147444 2014-12-02 07:45:00       0.3898
# 147450 2014-12-02 07:45:00       0.2440
#
# [24576 rows x 7 columns]

# %%
df2['Group'] = df2["cultivar"].map(str) + " " + df2["irrigation"].map(str)

df2['ProfileWater']= df['measurement'] * 300
df2['ProfileWater'][df['depth']== '0-15(InRow)'] = df['measurement'] * 150/2
df2['ProfileWater'][df['depth']== '0-15(btwRow)'] = df['measurement'] * 150/2
df2['ProfileWater'][df['depth']== '15-30'] = df['measurement'] * 150
df2['Group'] = df2["cultivar"].map(str) + " " + df2["irrigation"].map(str)
columns = ['measuretype', 'cultivar', 'irrigation', 'measurement']
new_data = df2.drop(columns, 1)
grouped_data = new_data.groupby(['Group', 'time', 'depth'])['ProfileWater'].mean()
new_group =pd.DataFrame(grouped_data)
new_data=new_group.reset_index()
new_data
# Out:
# c:\Users\cflsys\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\core\series.py:637: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame
#   self.where(~key, value, inplace=True)
# -c:7: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
#            Group                time         depth  ProfileWater
# 0     Dash  High 2014-12-01 00:00:00   0-15(InRow)     19.179375
# 1     Dash  High 2014-12-01 00:00:00  0-15(btwRow)     17.161875
# 2     Dash  High 2014-12-01 00:00:00       120-150    110.685000
# 3     Dash  High 2014-12-01 00:00:00         15-30     42.948750
# 4     Dash  High 2014-12-01 00:00:00       150-180    115.950000
# 5     Dash  High 2014-12-01 00:00:00         30-60     99.195000
# 6     Dash  High 2014-12-01 00:00:00         60-90    108.457500
# 7     Dash  High 2014-12-01 00:00:00        90-120    103.897500
# 8     Dash  High 2014-12-01 00:15:00   0-15(InRow)     19.181250
# 9     Dash  High 2014-12-01 00:15:00  0-15(btwRow)     17.163750
# 10    Dash  High 2014-12-01 00:15:00       120-150    110.677500
# 11    Dash  High 2014-12-01 00:15:00         15-30     42.948750
# 12    Dash  High 2014-12-01 00:15:00       150-180    115.950000
# 13    Dash  High 2014-12-01 00:15:00         30-60     99.187500
# 14    Dash  High 2014-12-01 00:15:00         60-90    108.480000
# 15    Dash  High 2014-12-01 00:15:00        90-120    103.897500
# 16    Dash  High 2014-12-01 00:30:00   0-15(InRow)     19.177500
# 17    Dash  High 2014-12-01 00:30:00  0-15(btwRow)     17.161875
# 18    Dash  High 2014-12-01 00:30:00       120-150    110.685000
# 19    Dash  High 2014-12-01 00:30:00         15-30     42.948750
# 20    Dash  High 2014-12-01 00:30:00       150-180    115.972500
# 21    Dash  High 2014-12-01 00:30:00         30-60     99.187500
# 22    Dash  High 2014-12-01 00:30:00         60-90    108.472500
# 23    Dash  High 2014-12-01 00:30:00        90-120    103.882500
# 24    Dash  High 2014-12-01 00:45:00   0-15(InRow)     19.171875
# 25    Dash  High 2014-12-01 00:45:00  0-15(btwRow)     17.156250
# 26    Dash  High 2014-12-01 00:45:00       120-150    110.677500
# 27    Dash  High 2014-12-01 00:45:00         15-30     42.937500
# 28    Dash  High 2014-12-01 00:45:00       150-180    115.972500
# 29    Dash  High 2014-12-01 00:45:00         30-60     99.195000
# ...          ...                 ...           ...           ...
# 6114  Omaka Mid  2014-12-02 07:00:00       120-150    123.862500
# 6115  Omaka Mid  2014-12-02 07:00:00         15-30     24.907500
# 6116  Omaka Mid  2014-12-02 07:00:00       150-180     97.762500
# 6117  Omaka Mid  2014-12-02 07:00:00         30-60     83.032500
# 6118  Omaka Mid  2014-12-02 07:00:00         60-90     96.300000
# 6119  Omaka Mid  2014-12-02 07:00:00        90-120     86.100000
# 6120  Omaka Mid  2014-12-02 07:15:00   0-15(InRow)      7.546875
# 6121  Omaka Mid  2014-12-02 07:15:00  0-15(btwRow)      7.348125
# 6122  Omaka Mid  2014-12-02 07:15:00       120-150    123.855000
# 6123  Omaka Mid  2014-12-02 07:15:00         15-30     24.892500
# 6124  Omaka Mid  2014-12-02 07:15:00       150-180     97.777500
# 6125  Omaka Mid  2014-12-02 07:15:00         30-60     83.032500
# 6126  Omaka Mid  2014-12-02 07:15:00         60-90     96.300000
# 6127  Omaka Mid  2014-12-02 07:15:00        90-120     86.085000
# 6128  Omaka Mid  2014-12-02 07:30:00   0-15(InRow)      7.546875
# 6129  Omaka Mid  2014-12-02 07:30:00  0-15(btwRow)      7.348125
# 6130  Omaka Mid  2014-12-02 07:30:00       120-150    123.862500
# 6131  Omaka Mid  2014-12-02 07:30:00         15-30     24.892500
# 6132  Omaka Mid  2014-12-02 07:30:00       150-180     97.777500
# 6133  Omaka Mid  2014-12-02 07:30:00         30-60     82.972500
# 6134  Omaka Mid  2014-12-02 07:30:00         60-90     96.270000
# 6135  Omaka Mid  2014-12-02 07:30:00        90-120     86.107500
# 6136  Omaka Mid  2014-12-02 07:45:00   0-15(InRow)      7.548750
# 6137  Omaka Mid  2014-12-02 07:45:00  0-15(btwRow)      7.346250
# 6138  Omaka Mid  2014-12-02 07:45:00       120-150    123.862500
# 6139  Omaka Mid  2014-12-02 07:45:00         15-30     24.896250
# 6140  Omaka Mid  2014-12-02 07:45:00       150-180     97.777500
# 6141  Omaka Mid  2014-12-02 07:45:00         30-60     82.957500
# 6142  Omaka Mid  2014-12-02 07:45:00         60-90     96.255000
# 6143  Omaka Mid  2014-12-02 07:45:00        90-120     86.085000
#
# [6144 rows x 4 columns]

# %%
data = pd.read_csv(r'H:\notebooks\testdata.csv')
data['Group'] = data["Crop"].map(str) + " " + data["Irrifation"].map(str) 
grouped_data = data.groupby(['Group', 'Time', 'Plot', 'Depth'])['Value'].mean()
new_group=pd.DataFrame(grouped_data)
new_data=new_group.reset_index()
#list(new_data.columns.values)
#new_group.index.names
new_data
# Out:
#           Group  Time  Plot         Depth   Value
# 0    Dash  High     1   206   0-15(InRow)  0.2264
# 1    Dash  High     1   206  0-15(btwRow)  0.2021
# 2    Dash  High     1   206       120-150  0.4325
# 3    Dash  High     1   206         15-30  0.2535
# 4    Dash  High     1   206       150-180  0.4211
# 5    Dash  High     1   206         30-60  0.2867
# 6    Dash  High     1   206         60-90  0.3438
# 7    Dash  High     1   206        90-120  0.2937
# 8    Dash  High     1   211   0-15(InRow)  0.1769
# 9    Dash  High     1   211  0-15(btwRow)  0.1687
# 10   Dash  High     1   211       120-150  0.4052
# 11   Dash  High     1   211         15-30  0.2194
# 12   Dash  High     1   211       150-180  0.3470
# 13   Dash  High     1   211         30-60  0.3331
# 14   Dash  High     1   211         60-90  0.3822
# 15   Dash  High     1   211        90-120  0.3432
# 16   Dash  High     1   215   0-15(InRow)  0.1910
# 17   Dash  High     1   215  0-15(btwRow)  0.1569
# 18   Dash  High     1   215       120-150  0.3483
# 19   Dash  High     1   215         15-30  0.2903
# 20   Dash  High     1   215       150-180  0.3932
# 21   Dash  High     1   215         30-60  0.3529
# 22   Dash  High     1   215         60-90  0.3940
# 23   Dash  High     1   215        90-120  0.4251
# 24   Dash  High     1   221   0-15(InRow)  0.1936
# 25   Dash  High     1   221  0-15(btwRow)  0.1781
# 26   Dash  High     1   221       120-150  0.2961
# 27   Dash  High     1   221         15-30  0.2585
# 28   Dash  High     1   221       150-180  0.3860
# 29   Dash  High     1   221         30-60  0.3145
# ..          ...   ...   ...           ...     ...
# 738  Omaka High    12   202       120-150  0.3518
# 739  Omaka High    12   202         15-30  0.1829
# 740  Omaka High    12   202       150-180  0.4168
# 741  Omaka High    12   202         30-60  0.2758
# 742  Omaka High    12   202         60-90  0.3857
# 743  Omaka High    12   202        90-120  0.3961
# 744  Omaka High    12   208   0-15(InRow)  0.1763
# 745  Omaka High    12   208  0-15(btwRow)  0.1775
# 746  Omaka High    12   208       120-150  0.2362
# 747  Omaka High    12   208         15-30  0.1986
# 748  Omaka High    12   208       150-180  0.4192
# 749  Omaka High    12   208         30-60  0.3289
# 750  Omaka High    12   208         60-90  0.3729
# 751  Omaka High    12   208        90-120  0.3702
# 752  Omaka High    12   213   0-15(InRow)  0.1873
# 753  Omaka High    12   213  0-15(btwRow)  0.1841
# 754  Omaka High    12   213       120-150  0.4038
# 755  Omaka High    12   213         15-30  0.2466
# 756  Omaka High    12   213       150-180  0.3011
# 757  Omaka High    12   213         30-60  0.3967
# 758  Omaka High    12   213         60-90  0.3368
# 759  Omaka High    12   213        90-120  0.3305
# 760  Omaka High    12   222   0-15(InRow)  0.1538
# 761  Omaka High    12   222  0-15(btwRow)  0.1830
# 762  Omaka High    12   222       120-150  0.3418
# 763  Omaka High    12   222         15-30  0.1951
# 764  Omaka High    12   222       150-180  0.3610
# 765  Omaka High    12   222         30-60  0.2974
# 766  Omaka High    12   222         60-90  0.2458
# 767  Omaka High    12   222        90-120  0.3700
#
# [768 rows x 5 columns]

# %%
plot=sns.factorplot("time", "ProfileWater", "Group", data=new_data, col="depth", col_wrap=1, size=8,aspect=15, palette="Set2", kind="point", ci=0)
plot

# %%
g = sns.FacetGrid(new_data, col="depth", hue="Group", palette="Set2")
g.map(sns.factorplot, "time", "ProfileWater")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-89a15859542b> in <module>()
#       1 g = sns.FacetGrid(new_data, col="depth", hue="Group", palette="Set2")
# ----> 2 g.map(sns.factorplot, "time", "ProfileWater")
#
# c:\Users\cflsys\AppData\Local\Continuum\Anaconda\lib\site-packages\seaborn\axisgrid.pyc in map(self, func, *args, **kwargs)
#     443
#     444             # Draw the plot
# --> 445             self._facet_plot(func, ax, plot_args, kwargs)
#     446
#     447         # Finalize the annotations and layout
#
# c:\Users\cflsys\AppData\Local\Continuum\Anaconda\lib\site-packages\seaborn\axisgrid.pyc in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     527
#     528         # Draw the plot
# --> 529         func(*plot_args, **plot_kwargs)
#     530
#     531         # Sort out the supporting information
#
# TypeError: factorplot() got an unexpected keyword argument 'color'
